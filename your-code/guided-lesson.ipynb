# %% [markdown]
# # Parsing APIs Example

# %% [markdown]
# ## Intro
#
# Now we will take a look on a real data. When you parse data from web you will often meet API based web-pages.
#
# For example [zalando.fr](https://www.zalando.fr/accueil-homme/) is API based web-page.
#
# In this guided lab you will learn how to obtain the links from webpages and extract the data. Read through this doc, execute the cells in order and make sure you understand the explanations.
#
# *Note: This guided lab uses Google Chrome. Other browsers like Safari and Firefox have similar tools for developers but they work differently. To save your time in following this lab, it is strongly recommended that you install and use Google Chrome.*

# %% [markdown]
# ## Obtaining the link
#
# Zalando is discount e-store where you can buy clothes and accesories with discount. When we go to the web-page, we can choose different sections. First the general process will be shown using [Children section](https://www.zalando.fr/accueil-enfant/) as example.
#
# Here we will parse data about promotions only. Therefore, final output will be the DataFrame with all the goods under discount.
#
# [![Image from Gyazo](https://i.gyazo.com/fa4874d8e81c7570273bbfb853d66308.png)](https://gyazo.com/fa4874d8e81c7570273bbfb853d66308)
#
#
# We go to Promos page. Right click of mouse shows us a list of actions possible, from which we select Inspect.
#
# <img src='https://i.gyazo.com/bccbd11d69c9040dc98758d443e32052.png' width="400">
#
#
# You will see the menu dropdown on the right side or on the bottom of the window. There you should click on Network:
#
#
# [![Image from Gyazo](https://i.gyazo.com/f7e0db81cbfee67694183d1a7640bf81.png)](https://gyazo.com/f7e0db81cbfee67694183d1a7640bf81)

# %% [markdown]
# Right after the developer part will change showing the files behind the page. In order to obtain only useful files we select the following settings:
# 1. Preserve Log
# 2. Select XHR files.
#
# [![Image from Gyazo](https://i.gyazo.com/9a899d4441d9d93e795f79747f1e47d5.png)](https://gyazo.com/9a899d4441d9d93e795f79747f1e47d5)
#
# In order to obtain some files we need to scrool down and go forward to second page.
#
# [![Image from Gyazo](https://i.gyazo.com/0956eb3d5125075a236c9a439c7749c7.png)](https://gyazo.com/0956eb3d5125075a236c9a439c7749c7)
#
# In the Network panel you can see the following files being uploaded. All the data on the web-page is uploaded from the json file, which is one of the following. It is important to understand which file contains what kind of information.
#
# <a href="https://gyazo.com/cf97a655869f0b22df0ada1cb2a41c3c"><img src="https://i.gyazo.com/cf97a655869f0b22df0ada1cb2a41c3c.png" alt="Image from Gyazo" width="724.8"/></a>
#
# When you find what kind of information you need for the data to be uploaded you just test it. Here we need the article... file:
#
# <a href="https://gyazo.com/78b35bf492994b3f35c0564a21da202a"><img src="https://i.gyazo.com/78b35bf492994b3f35c0564a21da202a.png" alt="Image from Gyazo" width="727.2"/></a>
#
# When we test the link in Chrome inkognito mode we obtain the proper json file:
#
#
# <a href="https://gyazo.com/b60453fa98454fa29771c731a5174443"><img src="https://i.gyazo.com/b60453fa98454fa29771c731a5174443.png" alt="Image from Gyazo" width="1530.4"/></a>

# %% [markdown]
# In order to change the objects in the json file (kind of pagination), you need to change the offset (the number of the first element on the page). in fact, if you take a look on the link, it is easy to unerstand the structure of the link.
#
# # Reading the data
#
# Now the party rocks! When we know how can we obtain the data, it is not a problem to obtain the whole database with all the data from the web-page.
# In this lab you will collect your database of Zalando products. You select which goods you want to track. You can define as many filters to your data as you want. Just make sure that the data represents the filters.

# %%
import json
from urllib.request import urlopen
import pandas as pd
from pandas.io.json import json_normalize

# %%
# Paste the url you obtained for your data
url='https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&genders=FEMALE&limit=84&offset=84'

# %% [markdown]
# #### Collect first 84 object of the of the data (1st page)
#
# Your output should be a Pandas DataFrame of goods. Each row should contain only text or numbers, having *family_articles, flags, media* and *sizes* remaining lists (they are exceptions).

# %%
# Your code

response = urlopen(url).read().decode("utf-8")
results = json.loads(response)
results


flattened_data = json_normalize(results)

flattened_data1 = json_normalize(flattened_data.articles[0])
flattened_data1
# Out:
# C:\Users\oscar\AppData\Local\Temp/ipykernel_2612/296306620.py:8: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   flattened_data = json_normalize(results)
# C:\Users\oscar\AppData\Local\Temp/ipykernel_2612/296306620.py:10: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   flattened_data1 = json_normalize(flattened_data.articles[0])
#               sku                                               name  \
# 0   NI113D0CN-Q11  BLAZER MID 77 - Baskets montantes - white/blac...
# 1   AD543A2JM-K11  DURAMO  - Chaussures d'entraînement et de fitn...
# 2   AD116D110-A11         STAN SMITH UNISEX - Baskets basses - white
# 3   QU153I00J-K12  EVERYDAYBPYTH B BKPK KVJ0 - Sac à dos - light ...
# 4   N1243A0ZC-K11  PICO 5 UNISEX - Chaussures d'entraînement et d...
# ..            ...                                                ...
# 79  AD116D13V-Q11  ZX 8000 LEGO UNISEX - Baskets basses - core bl...
# 80  C7643G04A-Q11  LEGACY AMERICAN TAPE HOODED FULL ZIP - Sweat à...
# 81  EL943G004-Q11  NORITIO UNISEX - T-shirt à manches longues - b...
# 82  G5213G04K-B11                                FERN - Tongs - nude
# 83  NI113D0CQ-A11  COURT BOROUGH 2  - Baskets basses - white/hype...
#
#                                                 sizes  \
# 0                  [28, 28.5, 29.5, 30, 32, 33.5, 34]
# 1   [28, 29, 30, 31, 32, 33, 36, 38, 36 2/3, 38 2/...
# 2              [35.5, 36, 38, 36 2/3, 37 1/3, 38 2/3]
# 3                                          [One Size]
# 4    [28.5, 29.5, 30, 31, 31.5, 32, 33, 33.5, 34, 35]
# ..                                                ...
# 79                   [36, 38, 36 2/3, 37 1/3, 38 2/3]
# 80                           [11-12a, 13-14a, 15-16a]
# 81                           [10-11a, 12-13a, 13-14a]
# 82                                   [32, 33, 34, 35]
# 83                       [19.5, 21, 22, 23.5, 25, 27]
#
#                                               url_key  \
# 0   nike-sportswear-blazer-mid-77-baskets-montante...
# 1   adidas-performance-duramo-sl-shoes-chaussures-...
# 2   adidas-originals-stan-smith-unisex-baskets-bas...
# 3         quiksilver-everyday-sac-a-dos-qu153i00j-k12
# 4   nike-performance-pico-5-chaussures-dentraineme...
# ..                                                ...
# 79  adidas-originals-zx-8000-lego-unisex-baskets-b...
# 80  champion-legacy-american-tape-hooded-full-zip-...
# 81             ellesse-sweatshirt-black-el943g004-q11
# 82             gioseppo-fern-tongs-nude-g5213g04k-b11
# 83  nike-sportswear-court-borough-2-baskets-basses...
#
#                                                 media          brand_name  \
# 0   [{'path': 'spp-media-p1/f174a08493b24f5bbae335...     Nike Sportswear
# 1   [{'path': 'spp-media-p1/403b5b8a3a19431c8527fa...  adidas Performance
# 2   [{'path': 'spp-media-p1/8438b6a7cae6432f844fac...    adidas Originals
# 3   [{'path': 'spp-media-p1/fc034b390b193ed0883ce1...          Quiksilver
# 4   [{'path': 'spp-media-p1/333574dbaf1737a8b408f7...    Nike Performance
# ..                                                ...                 ...
# 79  [{'path': 'spp-media-p1/960d79d4236a40d7957801...    adidas Originals
# 80  [{'path': 'spp-media-p1/cf5cfd6e654e3554b3cb22...            Champion
# 81  [{'path': 'spp-media-p1/e7fd852895da368f80dda2...             Ellesse
# 82  [{'path': 'spp-media-p1/d4ac66c37141415784825f...            Gioseppo
# 83  [{'path': 'spp-media-p1/a0683cc9de184e14bced8f...     Nike Sportswear
#
#     is_premium family_articles  \
# 0        False              []
# 1        False              []
# 2        False              []
# 3        False              []
# 4        False              []
# ..         ...             ...
# 79       False              []
# 80       False              []
# 81       False              []
# 82       False              []
# 83       False              []
#
#                                                 flags product_group  \
# 0   [{'key': 'campaign', 'value': 'Hot Drop', 'tra...          shoe
# 1   [{'key': 'discountRate', 'value': '-40%', 'tra...          shoe
# 2   [{'key': 'discountRate', 'value': 'Jusqu’à -40...          shoe
# 3   [{'key': 'discountRate', 'value': '-65%', 'tra...   accessoires
# 4   [{'key': 'discountRate', 'value': 'Jusqu’à -25...          shoe
# ..                                                ...           ...
# 79  [{'key': 'campaign', 'value': 'Hot Drop', 'tra...          shoe
# 80  [{'key': 'discountRate', 'value': '-45%', 'tra...      clothing
# 81  [{'key': 'discountRate', 'value': '-60%', 'tra...      clothing
# 82  [{'key': 'discountRate', 'value': '-50%', 'tra...          shoe
# 83  [{'key': 'discountRate', 'value': '-10%', 'tra...          shoe
#
#    delivery_promises price.original price.promotional  \
# 0                 []       69,95  €          48,95  €
# 1                 []       42,95  €          25,75  €
# 2                 []       69,95  €          41,95  €
# 3                 []       35,99  €          12,69  €
# 4                 []       29,95  €          22,45  €
# ..               ...            ...               ...
# 79                []       94,95  €          33,45  €
# 80                []       39,95  €          21,95  €
# 81                []       44,95  €          17,95  €
# 82                []       59,95  €          29,95  €
# 83                []       29,95  €          26,95  €
#
#     price.has_different_prices  price.has_different_original_prices  \
# 0                        False                                False
# 1                        False                                False
# 2                         True                                False
# 3                        False                                False
# 4                         True                                False
# ..                         ...                                  ...
# 79                       False                                False
# 80                       False                                False
# 81                       False                                False
# 82                       False                                False
# 83                       False                                False
#
#     price.has_different_promotional_prices  \
# 0                                    False
# 1                                    False
# 2                                     True
# 3                                    False
# 4                                     True
# ..                                     ...
# 79                                   False
# 80                                   False
# 81                                   False
# 82                                   False
# 83                                   False
#
#     price.has_discount_on_selected_sizes_only amount
# 0                                       False    NaN
# 1                                       False    NaN
# 2                                       False    NaN
# 3                                       False    NaN
# 4                                       False    NaN
# ..                                        ...    ...
# 79                                      False    NaN
# 80                                      False    NaN
# 81                                      False    NaN
# 82                                      False    NaN
# 83                                      False    NaN
#
# [84 rows x 18 columns]

# %% [markdown]
# #### Collect all the objects from selected filters. Total number of pages can be found in the same json. Use *sku* column as index.
#
# Your output should be a Pandas DataFrame of goods. Each row should contain only text or numbers, having family_articles, flags, media and sizes remaining lists (they are exceptions).

# %%
# Get the total number of pages
total_pages=results['pagination']['page_count']

# Your code
df=pd.DataFrame()
for i in range(1):
    k=84*i
    url=f'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&genders=FEMALE&limit=84&offset={k}&sort=sale'
    response = urlopen(url).read().decode("utf-8")
    results = json.loads(response)
    flattened_data = json_normalize(results)
    flattened_data1 = json_normalize(flattened_data.articles[0])
    flattened_data1=flattened_data1.set_index('sku')
    df = df.append(flattened_data1)

df
# Out:
# C:\Users\oscar\AppData\Local\Temp/ipykernel_2612/1704738112.py:11: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   flattened_data = json_normalize(results)
# C:\Users\oscar\AppData\Local\Temp/ipykernel_2612/1704738112.py:12: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   flattened_data1 = json_normalize(flattened_data.articles[0])
#                                                             name  \
# sku
# NI116D0A1-A11  REACT LIVE UNISEX - Baskets basses - white/bla...
# LE223G01Z-C11                       T-shirt imprimé - gris chine
# AD116D0PK-Q11  TEAM COURT  - Baskets basses - core black/foot...
# LE216D01N-A13      SOHO - Baskets basses - white/metallic silver
# AD116D0SS-A12  STAN SMITH UNISEX - Baskets basses - footwear ...
# ...                                                          ...
# TH343D012-A11  YOUTH MOUNTAIN TEE UNISEX - T-shirt imprimé - ...
# GP023B0BJ-K11     TODDLER GIRL OVERALL - Salopette - medium wash
# NI116D07T-A11  AIR MAX 2090 UNISEX - Baskets basses - summit ...
# VA216D05F-L11  OLD SKOOL UNISEX - Baskets basses - scuba blue...
# 6MO13G00B-A11                                   Sandales - white
#
#                                                            sizes  \
# sku
# NI116D0A1-A11           [35.5, 36, 36.5, 37.5, 38, 38.5, 39, 40]
# LE223G01Z-C11                               [10a, 12a, 14a, 16a]
# AD116D0PK-Q11             [35.5, 36, 38, 36 2/3, 37 1/3, 38 2/3]
# LE216D01N-A13                                   [36, 37, 38, 39]
# AD116D0SS-A12                               [19, 24, 25, 26, 27]
# ...                                                          ...
# TH343D012-A11                        [10a/12a, 12a/14a, 16a/18a]
# GP023B0BJ-K11                           [18-24m, 2a, 3a, 4a, 5a]
# NI116D07T-A11                             [35.5, 36.5, 38.5, 40]
# VA216D05F-L11                           [29, 30, 31, 32, 33, 34]
# 6MO13G00B-A11  [27, 28, 30, 31, 32, 33, 34, 35, 36, 37, 38, 3...
#
#                                                          url_key  \
# sku
# NI116D0A1-A11  nike-sportswear-react-live-unisex-baskets-bass...
# LE223G01Z-C11           levisr-bat-t-shirt-imprime-le223g01z-c11
# AD116D0PK-Q11  adidas-originals-team-court-baskets-basses-ad1...
# LE216D01N-A13  levis-soho-baskets-basses-whitemetallic-silver...
# AD116D0SS-A12  adidas-originals-stan-smith-sports-inspired-sh...
# ...                                                          ...
# TH343D012-A11  the-north-face-youth-mountain-tee-unisex-t-shi...
# GP023B0BJ-K11  gap-toddler-girl-overall-salopette-medium-wash...
# NI116D07T-A11  nike-sportswear-air-max-2090-unisex-baskets-ba...
# VA216D05F-L11  vans-old-skool-unisex-baskets-basses-scuba-blu...
# 6MO13G00B-A11              moschino-sandales-white-6mo13g00b-a11
#
#                                                            media  \
# sku
# NI116D0A1-A11  [{'path': 'spp-media-p1/1038c8ba11354a18b5a0f3...
# LE223G01Z-C11  [{'path': 'spp-media-p1/fd9deda3e82f36d2817e08...
# AD116D0PK-Q11  [{'path': 'spp-media-p1/8c0e4514252d392bbc7d62...
# LE216D01N-A13  [{'path': 'spp-media-p1/42a34a9256c13d4c9f4510...
# AD116D0SS-A12  [{'path': 'spp-media-p1/525cfe5b176f320bbe945f...
# ...                                                          ...
# TH343D012-A11  [{'path': 'spp-media-p1/a7a21006265c48efbcf01e...
# GP023B0BJ-K11  [{'path': 'spp-media-p1/ff924e87e7674b5a94cdf7...
# NI116D07T-A11  [{'path': 'spp-media-p1/c19f55f3035a451fafce0b...
# VA216D05F-L11  [{'path': 'spp-media-p1/d50e107654114201820b63...
# 6MO13G00B-A11  [{'path': 'spp-media-p1/e8a2f333b60732e488ca21...
#
#                      brand_name  is_premium family_articles  \
# sku
# NI116D0A1-A11   Nike Sportswear       False              []
# LE223G01Z-C11           Levi's®       False              []
# AD116D0PK-Q11  adidas Originals       False              []
# LE216D01N-A13           Levi's®       False              []
# AD116D0SS-A12  adidas Originals       False              []
# ...                         ...         ...             ...
# TH343D012-A11    The North Face       False              []
# GP023B0BJ-K11               GAP       False              []
# NI116D07T-A11   Nike Sportswear       False              []
# VA216D05F-L11              Vans       False              []
# 6MO13G00B-A11          MOSCHINO        True              []
#
#                                                            flags  \
# sku
# NI116D0A1-A11  [{'key': 'discountRate', 'value': '-65%', 'tra...
# LE223G01Z-C11  [{'key': 'discountRate', 'value': 'Jusqu’à -60...
# AD116D0PK-Q11  [{'key': 'discountRate', 'value': '-65%', 'tra...
# LE216D01N-A13  [{'key': 'discountRate', 'value': '-70%', 'tra...
# AD116D0SS-A12  [{'key': 'discountRate', 'value': '-55%', 'tra...
# ...                                                          ...
# TH343D012-A11  [{'key': 'discountRate', 'value': '-50%', 'tra...
# GP023B0BJ-K11  [{'key': 'discountRate', 'value': '-70%', 'tra...
# NI116D07T-A11  [{'key': 'discountRate', 'value': 'Jusqu’à -65...
# VA216D05F-L11  [{'key': 'discountRate', 'value': '-50%', 'tra...
# 6MO13G00B-A11  [{'key': 'discountRate', 'value': '-60%', 'tra...
#
#               product_group delivery_promises price.original  \
# sku
# NI116D0A1-A11          shoe                []       84,95  €
# LE223G01Z-C11      clothing                []       19,95  €
# AD116D0PK-Q11          shoe                []       59,95  €
# LE216D01N-A13          shoe                []       69,95  €
# AD116D0SS-A12          shoe                []       46,95  €
# ...                     ...               ...            ...
# TH343D012-A11      clothing                []       24,95  €
# GP023B0BJ-K11      clothing                []       34,95  €
# NI116D07T-A11          shoe                []      129,95  €
# VA216D05F-L11          shoe                []       49,95  €
# 6MO13G00B-A11          shoe                []      145,00  €
#
#               price.promotional  price.has_different_prices  \
# sku
# NI116D0A1-A11          29,95  €                       False
# LE223G01Z-C11           8,00  €                        True
# AD116D0PK-Q11          20,95  €                       False
# LE216D01N-A13          20,95  €                       False
# AD116D0SS-A12          21,35  €                       False
# ...                         ...                         ...
# TH343D012-A11          12,45  €                       False
# GP023B0BJ-K11          10,65  €                       False
# NI116D07T-A11          44,95  €                        True
# VA216D05F-L11          24,95  €                       False
# 6MO13G00B-A11          58,00  €                       False
#
#                price.has_different_original_prices  \
# sku
# NI116D0A1-A11                                False
# LE223G01Z-C11                                False
# AD116D0PK-Q11                                False
# LE216D01N-A13                                False
# AD116D0SS-A12                                False
# ...                                            ...
# TH343D012-A11                                False
# GP023B0BJ-K11                                False
# NI116D07T-A11                                False
# VA216D05F-L11                                False
# 6MO13G00B-A11                                False
#
#                price.has_different_promotional_prices  \
# sku
# NI116D0A1-A11                                   False
# LE223G01Z-C11                                    True
# AD116D0PK-Q11                                   False
# LE216D01N-A13                                   False
# AD116D0SS-A12                                   False
# ...                                               ...
# TH343D012-A11                                   False
# GP023B0BJ-K11                                   False
# NI116D07T-A11                                    True
# VA216D05F-L11                                   False
# 6MO13G00B-A11                                   False
#
#                price.has_discount_on_selected_sizes_only amount
# sku
# NI116D0A1-A11                                      False    NaN
# LE223G01Z-C11                                      False    NaN
# AD116D0PK-Q11                                      False    NaN
# LE216D01N-A13                                      False    NaN
# AD116D0SS-A12                                      False    NaN
# ...                                                  ...    ...
# TH343D012-A11                                      False    NaN
# GP023B0BJ-K11                                      False    NaN
# NI116D07T-A11                                      False    NaN
# VA216D05F-L11                                      False    NaN
# 6MO13G00B-A11                                      False    NaN
#
# [84 rows x 17 columns]

# %% [markdown]
# #### Display the trending brand in DataFrame

# %%
df.brand_name.value_counts().index[0]
# Out:
# 'adidas Originals'

# %% [markdown]
# #### Display the brand with maximal total discount (sum of discounts on all goods)

# %%
#Our data is still text. Convert prices into numbers:
df['price.original']=df['price.original'].str.extract('(\d*,\d*)')
df['price.promotional']=df['price.promotional'].str.extract('(\d*,\d*)')

df['price.original'] = [x.replace(',', '.') for x in df['price.original']]
df['price.promotional'] = [x.replace(',', '.') for x in df['price.promotional']]

# %%
df['discount_amount']=df['price.original'].astype(float)-df['price.promotional'].astype(float)
df1=df.copy()

# %%
total_disc=df1.groupby(['brand_name']).sum().discount_amount

# %%
total_disc.sort_values(ascending=False).index[0]
# Out:
# 'adidas Originals'

# %% [markdown]
# #### Display the brands without discount at all

# %%
total_disc[total_disc==0]
# Out:
# Series([], Name: discount_amount, dtype: float64)
